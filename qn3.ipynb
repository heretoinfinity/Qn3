# %% [markdown]
# Import files

# %%
import pandas as pd
from bokeh.
from sqlalchemy import create_engine

# %%
df1=pd.read_csv("./supplement.csv")
df1
# Out:
#     StateFIPS                 State WIC participants FY 2009  \
# 0         1.0               Alabama                  140,810
# 1         2.0                Alaska                   25,816
# 2         4.0               Arizona                  208,873
# 3         5.0              Arkansas                   94,107
# 4         6.0            California                1,439,006
# 5         8.0              Colorado                  107,930
# 6         9.0           Connecticut                   60,148
# 7        10.0              Delaware                   24,028
# 8        11.0  District of Columbia                   17,473
# 9        12.0               Florida                  505,671
# 10       13.0               Georgia                  499,213
# 11       15.0                Hawaii                   36,320
# 12       16.0                 Idaho                   46,175
# 13       17.0              Illinois                  309,870
# ...

# %%
df1.describe()
# Out:
#        StateFIPS
# count  51.000000
# mean   28.960784
# std    15.832828
# min     1.000000
# 25%    16.500000
# 50%    29.000000
# 75%    41.500000
# max    56.000000
